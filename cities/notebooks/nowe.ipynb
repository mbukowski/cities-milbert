# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [14, 14]
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
class Parameters:
    POPULATION = 'pop_rate'
    MIGRATION = 'migr_rate'
    WORKING_AGE = 'age_rate'
    EMPLOYMENT = 'empl_rate'
    UNEMPLOYED = 'unempl_rate'
    REVENUE = 'revenue_rate'

# %%
df = pd.ExcelFile('new_data.xlsx')

# %%
df1 = pd.read_excel(df,'summary')

# %%
df1.columns
# Out:
# Index(['unit_id', 'teryt_id', 'name', 'level', 'kind', 'period_start',
#        'period_end', 'population_start', 'population_end', 'type', 'pop_rate',
#        'pop_points', 'migr_rate', 'migr_points', 'age_rate', 'age_points',
#        'empl_rate', 'empl_points', 'unempl_rate', 'unempl_points',
#        'revenue_rate', 'revenue_points', 'score', 'status'],
#       dtype='object')

# %%
df1
# Out:
#            unit_id  teryt_id      name  level  kind  period_start  period_end  \
# 0      11212001011   1201011   Bochnia      6     1          2003        2008
# 1      11212001011   1201011   Bochnia      6     1          2004        2009
# 2      11212001011   1201011   Bochnia      6     1          2005        2010
# 3      11212001011   1201011   Bochnia      6     1          2006        2011
# 4      11212001011   1201011   Bochnia      6     1          2007        2012
# ...            ...       ...       ...    ...   ...           ...         ...
# 34673  71427338053   1438053  Wiskitki      6     3          2012        2017
# 34674  71427338053   1438053  Wiskitki      6     3          2013        2018
# 34675  71427338053   1438053  Wiskitki      6     3          2014        2019
# 34676  71427338053   1438053  Wiskitki      6     3          2015        2020
# 34677  71427338053   1438053  Wiskitki      6     3          2016        2021
#
#        population_start  population_end type  ...  age_rate  age_points  \
# 0                 29423           29605    M  ...    0.0041           3
# 1                 29536           29748    M  ...    0.0019           3
# 2                 29487           30166    M  ...    0.0030           3
# 3                 29404           30300    M  ...    0.0018           3
# 4                 29444           30303    M  ...    0.0004           3
# ...                 ...             ...  ...  ...       ...         ...
# 34673                 0               0    S  ...   -0.0028           3
# 34674                 0               0    S  ...   -0.0032           3
# 34675                 0               0    S  ...   -0.0054           3
# 34676                 0               0    S  ...   -0.0037           3
# 34677                 0            1332    S  ...   -0.0053           3
#
#        empl_rate  empl_points  unempl_rate  unempl_points  revenue_rate  \
# 0         0.0385            3      -0.0079              1        0.1411
# 1         0.0235            2      -0.0048              1        0.1018
# 2         0.0383            3      -0.0039              4        0.0821
# 3         0.0291            3      -0.0007              2        0.0628
# 4         0.0192            2       0.0028              0        0.0716
# ...          ...          ...          ...            ...           ...
# 34673    -0.0418            0      -0.0027              0        0.2207
# 34674    -0.0114            0      -0.0044              0        0.1027
# 34675     0.1352            4      -0.0040              0        0.0643
# 34676     0.1266            4      -0.0027              1        0.1039
# 34677     0.2263            4      -0.0028              3        0.2308
#
#        revenue_points  score  status
# 0                   2     14       B
# 1                   2     13       C
# 2                   2     17       B
# 3                   2     15       B
# 4                   2     12       C
# ...               ...    ...     ...
# 34673               4     13       C
# 34674               4     13       C
# 34675               2     16       B
# 34676               3     18       B
# 34677               4     20       A
#
# [34678 rows x 24 columns]

# %%
dfu = pd.ExcelFile('data3.xlsx')
units = pd.read_excel(dfu,'units')

df1['functionality']=np.nan
for i in range(len(df1)):
    try:
        df1.loc[i,'functionality']=units[units['teryt_id']==df1.iloc[i,1]]['functionality'].values[0]
    except:
        df1.loc[i,'functionality']='J'

# %%
df1
# Out:
#            unit_id  teryt_id      name  level  kind  period_start  period_end  \
# 0      11212001011   1201011   Bochnia      6     1          2003        2008
# 1      11212001011   1201011   Bochnia      6     1          2004        2009
# 2      11212001011   1201011   Bochnia      6     1          2005        2010
# 3      11212001011   1201011   Bochnia      6     1          2006        2011
# 4      11212001011   1201011   Bochnia      6     1          2007        2012
# ...            ...       ...       ...    ...   ...           ...         ...
# 34673  71427338053   1438053  Wiskitki      6     3          2012        2017
# 34674  71427338053   1438053  Wiskitki      6     3          2013        2018
# 34675  71427338053   1438053  Wiskitki      6     3          2014        2019
# 34676  71427338053   1438053  Wiskitki      6     3          2015        2020
# 34677  71427338053   1438053  Wiskitki      6     3          2016        2021
#
#        population_start  population_end type  ...  age_points  empl_rate  \
# 0                 29423           29605    M  ...           3     0.0385
# 1                 29536           29748    M  ...           3     0.0235
# 2                 29487           30166    M  ...           3     0.0383
# 3                 29404           30300    M  ...           3     0.0291
# 4                 29444           30303    M  ...           3     0.0192
# ...                 ...             ...  ...  ...         ...        ...
# 34673                 0               0    S  ...           3    -0.0418
# 34674                 0               0    S  ...           3    -0.0114
# 34675                 0               0    S  ...           3     0.1352
# 34676                 0               0    S  ...           3     0.1266
# 34677                 0            1332    S  ...           3     0.2263
#
#        empl_points  unempl_rate  unempl_points  revenue_rate  revenue_points  \
# 0                3      -0.0079              1        0.1411               2
# 1                2      -0.0048              1        0.1018               2
# 2                3      -0.0039              4        0.0821               2
# 3                3      -0.0007              2        0.0628               2
# 4                2       0.0028              0        0.0716               2
# ...            ...          ...            ...           ...             ...
# 34673            0      -0.0027              0        0.2207               4
# 34674            0      -0.0044              0        0.1027               4
# 34675            4      -0.0040              0        0.0643               2
# 34676            4      -0.0027              1        0.1039               3
# 34677            4      -0.0028              3        0.2308               4
#
#        score  status  functionality
# 0         14       B              E
# 1         13       C              E
# 2         17       B              E
# 3         15       B              E
# 4         12       C              E
# ...      ...     ...            ...
# 34673     13       C              F
# 34674     13       C              F
# 34675     16       B              F
# 34676     18       B              F
# 34677     20       A              F
#
# [34678 rows x 25 columns]

# %%
def score_to_city_size(df, period_start=2006, types_colors={"L": "#f6b26b", "M": "#6d9eeb", "S":"#c27ba0",  "R":"#c11be4"}, path="", save=False):
    sns.boxplot(data=df[df['period_start']==period_start][['type','score']].sort_values(by='type'), x="type", y="score", palette=types_colors)
    plt.title(str(period_start)+"-"+str(period_start+5), fontsize=20)
    plt.xlabel('City size', fontsize=20)
    plt.ylabel('Score', fontsize=20)
    plt.tick_params(axis='both', which='major', labelsize=16)
    if save:
        plt.savefig(path+str(period_start)+"-"+str(period_start+5)+'.png')

# %%
score_to_city_size(df1, period_start=2010)

# %%
def score_by_f_type(df, period_start=2006, path="", save=False):
    my_pal = {"A": "#922d17", "B": "#b97a70", "C":"#e94524", "D":"#f49190", "E": "#f48029", "F":"#837c1e", "G": "#736ab0", "H": "#8bbf3e", "I": "#c8de85", "J": "#44bfed"}
    temp = df[df["period_start"]==period_start]
    sns.boxplot(data=temp[['score','functionality']].sort_values(by='functionality'), x="functionality", y="score", palette=my_pal)
    plt.title(str(period_start)+"-"+str(period_start+5), fontsize=20)
    plt.xlabel('Functionality', fontsize=20)
    plt.ylabel('Score', fontsize=20) 
    plt.tick_params(axis='both', which='major', labelsize=16)
    if save:
        plt.savefig(path+"functionality-"+str(period_start)+"-"+str(period_start+5)+'.png')

# %%
score_by_f_type(df1)

# %%
df1
# Out:
#            unit_id  teryt_id      name  level  kind  period_start  period_end  \
# 0      11212001011   1201011   Bochnia      6     1          2003        2008
# 1      11212001011   1201011   Bochnia      6     1          2004        2009
# 2      11212001011   1201011   Bochnia      6     1          2005        2010
# 3      11212001011   1201011   Bochnia      6     1          2006        2011
# 4      11212001011   1201011   Bochnia      6     1          2007        2012
# ...            ...       ...       ...    ...   ...           ...         ...
# 34673  71427338053   1438053  Wiskitki      6     3          2012        2017
# 34674  71427338053   1438053  Wiskitki      6     3          2013        2018
# 34675  71427338053   1438053  Wiskitki      6     3          2014        2019
# 34676  71427338053   1438053  Wiskitki      6     3          2015        2020
# 34677  71427338053   1438053  Wiskitki      6     3          2016        2021
#
#        population_start  population_end type  ...  age_points  empl_rate  \
# 0                 29423           29605    M  ...           3     0.0385
# 1                 29536           29748    M  ...           3     0.0235
# 2                 29487           30166    M  ...           3     0.0383
# 3                 29404           30300    M  ...           3     0.0291
# 4                 29444           30303    M  ...           3     0.0192
# ...                 ...             ...  ...  ...         ...        ...
# 34673                 0               0    S  ...           3    -0.0418
# 34674                 0               0    S  ...           3    -0.0114
# 34675                 0               0    S  ...           3     0.1352
# 34676                 0               0    S  ...           3     0.1266
# 34677                 0            1332    S  ...           3     0.2263
#
#        empl_points  unempl_rate  unempl_points  revenue_rate  revenue_points  \
# 0                3      -0.0079              1        0.1411               2
# 1                2      -0.0048              1        0.1018               2
# 2                3      -0.0039              4        0.0821               2
# 3                3      -0.0007              2        0.0628               2
# 4                2       0.0028              0        0.0716               2
# ...            ...          ...            ...           ...             ...
# 34673            0      -0.0027              0        0.2207               4
# 34674            0      -0.0044              0        0.1027               4
# 34675            4      -0.0040              0        0.0643               2
# 34676            4      -0.0027              1        0.1039               3
# 34677            4      -0.0028              3        0.2308               4
#
#        score  status  functionality
# 0         14       B              E
# 1         13       C              E
# 2         17       B              E
# 3         15       B              E
# 4         12       C              E
# ...      ...     ...            ...
# 34673     13       C              F
# 34674     13       C              F
# 34675     16       B              F
# 34676     18       B              F
# 34677     20       A              F
#
# [34678 rows x 25 columns]

# %%
def correlation(df, col1, col2, period_start=2006, path="", save=False):
    cor = np.corrcoef(df[df['period_start']==period_start][col1], df[df['period_start']==period_start][col2])[0,1]
    plt.scatter(df[df['period_start']==period_start][col1], df[df['period_start']==period_start][col2])
    plt.title("Correlation between "+col1+" and "+col2+" - period start = "+str(period_start)+
              "\n correlation value = "+str(cor), fontsize=20)
    plt.xlabel(col1, fontsize=20)
    plt.ylabel(col2, fontsize=20) 
    plt.tick_params(axis='both', which='major', labelsize=16)
    if save:
        plt.savefig(path+"Correlation between "+col1+" and "+col2+" - period start = "+str(period_start)+'.png')

# %%
correlation(df1, Parameters.POPULATION, Parameters.WORKING_AGE, period_start=2006)

# %%
from IPython.display import display
param_list = [Parameters.POPULATION, Parameters.MIGRATION, Parameters.WORKING_AGE, Parameters.EMPLOYMENT,
              Parameters.UNEMPLOYED, Parameters.REVENUE]

corr_plots = []
a = df1[df1["period_start"]==year][param_list].corr()
for year in range(2003, 2017):
    corr = df1[df1["period_start"]==year][param_list].corr()
    x = corr.style.background_gradient(cmap='coolwarm')
    print(year)
    display(x)
    if year != 2003:
        a += corr
a/(2017-2003)
# Out:
# 2003
# <style  type="text/css" >
# #T_1b7a4_row0_col0,#T_1b7a4_row1_col1,#T_1b7a4_row2_col2,#T_1b7a4_row3_col3,#T_1b7a4_row4_col4,#T_1b7a4_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_1b7a4_row0_col1{
#             background-color:  #df634e;
#             color:  #000000;
#         }#T_1b7a4_row0_col2{
#             background-color:  #d44e41;
#             color:  #000000;
#         }#T_1b7a4_row0_col3{
#             background-color:  #9fbfff;
#             color:  #000000;
#         }#T_1b7a4_row0_col4,#T_1b7a4_row4_col0,#T_1b7a4_row4_col1,#T_1b7a4_row4_col2,#T_1b7a4_row4_col3,#T_1b7a4_row4_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_1b7a4_row0_col5{
#             background-color:  #8db0fe;
#             color:  #000000;
#         }#T_1b7a4_row1_col0{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_1b7a4_row1_col2{
#             background-color:  #ec7f63;
#             color:  #000000;
#         }#T_1b7a4_row1_col3{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_1b7a4_row1_col4{
#             background-color:  #5f7fe8;
#             color:  #000000;
#         }#T_1b7a4_row1_col5{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_1b7a4_row2_col0{
#             background-color:  #d24b40;
#             color:  #f1f1f1;
#         }#T_1b7a4_row2_col1{
#             background-color:  #ef886b;
#             color:  #000000;
#         }#T_1b7a4_row2_col3{
#             background-color:  #94b6ff;
#             color:  #000000;
#         }#T_1b7a4_row2_col4{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_1b7a4_row2_col5,#T_1b7a4_row3_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_1b7a4_row3_col0{
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }#T_1b7a4_row3_col2{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_1b7a4_row3_col4{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_1b7a4_row3_col5{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_1b7a4_row5_col0{
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }#T_1b7a4_row5_col1{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_1b7a4_row5_col2{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_1b7a4_row5_col3{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_1b7a4_row5_col4{
#             background-color:  #516ddb;
#             color:  #000000;
#         }</style><table id="T_1b7a4_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pop_rate</th>        <th class="col_heading level0 col1" >migr_rate</th>        <th class="col_heading level0 col2" >age_rate</th>        <th class="col_heading level0 col3" >empl_rate</th>        <th class="col_heading level0 col4" >unempl_rate</th>        <th class="col_heading level0 col5" >revenue_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1b7a4_level0_row0" class="row_heading level0 row0" >pop_rate</th>
#                         <td id="T_1b7a4_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1b7a4_row0_col1" class="data row0 col1" >0.871428</td>
#                         <td id="T_1b7a4_row0_col2" class="data row0 col2" >0.903048</td>
#                         <td id="T_1b7a4_row0_col3" class="data row0 col3" >0.247913</td>
#                         <td id="T_1b7a4_row0_col4" class="data row0 col4" >-0.108676</td>
#                         <td id="T_1b7a4_row0_col5" class="data row0 col5" >0.232663</td>
#             </tr>
#             <tr>
#                         <th id="T_1b7a4_level0_row1" class="row_heading level0 row1" >migr_rate</th>
#                         <td id="T_1b7a4_row1_col0" class="data row1 col0" >0.871428</td>
#                         <td id="T_1b7a4_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1b7a4_row1_col2" class="data row1 col2" >0.795620</td>
#                         <td id="T_1b7a4_row1_col3" class="data row1 col3" >0.212017</td>
#                         <td id="T_1b7a4_row1_col4" class="data row1 col4" >0.021327</td>
#                         <td id="T_1b7a4_row1_col5" class="data row1 col5" >0.206093</td>
#             </tr>
#             <tr>
#                         <th id="T_1b7a4_level0_row2" class="row_heading level0 row2" >age_rate</th>
#                         <td id="T_1b7a4_row2_col0" class="data row2 col0" >0.903048</td>
#                         <td id="T_1b7a4_row2_col1" class="data row2 col1" >0.795620</td>
#                         <td id="T_1b7a4_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T

#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_e77d2_row5_col4{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }</style><table id="T_e77d2_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pop_rate</th>        <th class="col_heading level0 col1" >migr_rate</th>        <th class="col_heading level0 col2" >age_rate</th>        <th class="col_heading level0 col3" >empl_rate</th>        <th class="col_heading level0 col4" >unempl_rate</th>        <th class="col_heading level0 col5" >revenue_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e77d2_level0_row0" class="row_heading level0 row0" >pop_rate</th>
#                         <td id="T_e77d2_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_e77d2_row0_col1" class="data row0 col1" >0.786055</td>
#                         <td id="T_e77d2_row0_col2" class="data row0 col2" >0.874175</td>
#                         <td id="T_e77d2_row0_col3" class="data row0 col3" >0.259304</td>
#                         <td id="T_e77d2_row0_col4" class="data row0 col4" >-0.076238</td>
#                         <td id="T_e77d2_row0_col5" class="data row0 col5" >0.192854</td>
#             </tr>
#             <tr>
#                         <th id="T_e77d2_level0_row1" class="row_heading level0 row1" >migr_rate</th>
#                         <td id="T_e77d2_row1_col0" class="data row1 col0" >0.786055</td>
#                         <td id="T_e77d2_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_e77d2_row1_col2" class="data row1 col2" >0.660246</td>
#                         <td id="T_e77d2_row1_col3" class="data row1 col3" >0.240205</td>
#                         <td id="T_e77d2_row1_col4" class="data row1 col4" >0.097488</td>
#                         <td id="T_e77d2_row1_col5" class="data row1 col5" >0.179326</td>
#             </tr>
#             <tr>
#                         <th id="T_e77d2_level0_row2" class="row_heading level0 row2" >age_rate</th>
#                         <td id="T_e77d2_row2_col0" class="data row2 col0" >0.874175</td>
#                         <td id="T_e77d2_row2_col1" class="data row2 col1" >0.660246</td>
#                         <td id="T_e77d2_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_e77d2_row2_col3" class="data row2 col3" >0.247974</td>
#                         <td id="T_e77d2_row2_col4" class="data row2 col4" >-0.046348</td>
#                         <td id="T_e77d2_row2_col5" class="data row2 col5" >0.184793</td>
#             </tr>
#             <tr>
#                         <th id="T_e77d2_level0_row3" class="row_heading level0 row3" >empl_rate</th>
#                         <td id="T_e77d2_row3_col0" class="data row3 col0" >0.259304</td>
#                         <td id="T_e77d2_row3_col1" class="data row3 col1" >0.240205</td>
#                         <td id="T_e77d2_row3_col2" class="data row3 col2" >0.247974</td>
#                         <td id="T_e77d2_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_e77d2_row3_col4" class="data row3 col4" >-0.016255</td>
#                         <td id="T_e77d2_row3_col5" class="data row3 col5" >0.150260</td>
#             </tr>
#             <tr>
#                         <th id="T_e77d2_level0_row4" class="row_heading level0 row4" >unempl_rate</th>
#                         <td id="T_e77d2_row4_col0" class="data row4 col0" >-0.076238</td>
#                         <td id="T_e77d2_row4_col1" class="data row4 col1" >0.097488</td>
#                         <td id="T_e77d2_row4_col2" class="data row4 col2" >-0.046348</td>
#                         <td id="T_e77d2_row4_col3" class="data row4 col3" >-0.016255</td>
#                         <td id="T_e77d2_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_e77d2_row4_col5" class="data row4 col5" >-0.019857</td>
#             </tr>
#             <tr>
#                         <th id="T_e77d2_level0_row5" class="row_heading level0 row5" >revenue_rate</th>
#                         <td id="T_e77d2_row5_col0" class="data row5 col0" >0.192854</td>
#                         <td id="T_e77d2_row5_col1" class="data row5 col1" >0.179326</td>
#                         <td id="T_e77d2_row5_col2" class="data row5 col2" >0.184793</td>
#                         <td id="T_e77d2_row5_col3" class="data row5 col3" >0.150260</td>
#                         <td id="T_e77d2_row5_col4" class="data row5 col4" >-0.019857</td>
#                         <td id="T_e77d2_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>
# 2006
# <style  type="text/css" >
# #T_cb5fe_row0_col0,#T_cb5fe_row1_col1,#T_cb5fe_row2_col2,#T_cb5fe_row3_col3,#T_cb5fe_row4_col4,#T_cb5fe_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_cb5fe_row0_col1{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_cb5fe_row0_col2{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_cb5fe_row0_col3{
#             background-color:  #88abfd;
#             color:  #000000;
#         }#T
row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8a7b7_row0_col1" class="data row0 col1" >0.881533</td>
#                         <td id="T_8a7b7_row0_col2" class="data row0 col2" >0.884339</td>
#                         <td id="T_8a7b7_row0_col3" class="data row0 col3" >0.275908</td>
#                         <td id="T_8a7b7_row0_col4" class="data row0 col4" >0.212895</td>
#                         <td id="T_8a7b7_row0_col5" class="data row0 col5" >0.172289</td>
#             </tr>
#             <tr>
#                         <th id="T_8a7b7_level0_row1" class="row_heading level0 row1" >migr_rate</th>
#                         <td id="T_8a7b7_row1_col0" class="data row1 col0" >0.881533</td>
#                         <td id="T_8a7b7_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_8a7b7_row1_col2" class="data row1 col2" >0.776017</td>
#                         <td id="T_8a7b7_row1_col3" class="data row1 col3" >0.240818</td>
#                         <td id="T_8a7b7_row1_col4" class="data row1 col4" >0.245617</td>
#                         <td id="T_8a7b7_row1_col5" class="data row1 col5" >0.109498</td>
#             </tr>
#             <tr>
#                         <th id="T_8a7b7_level0_row2" class="row_heading level0 row2" >age_rate</th>
#                         <td id="T_8a7b7_row2_col0" class="data row2 col0" >0.884339</td>
#                         <td id="T_8a7b7_row2_col1" class="data row2 col1" >0.776017</td>
#                         <td id="T_8a7b7_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_8a7b7_row2_col3" class="data row2 col3" >0.285475</td>
#                         <td id="T_8a7b7_row2_col4" class="data row2 col4" >0.172176</td>
#                         <td id="T_8a7b7_row2_col5" class="data row2 col5" >0.276742</td>
#             </tr>
#             <tr>
#                         <th id="T_8a7b7_level0_row3" class="row_heading level0 row3" >empl_rate</th>
#                         <td id="T_8a7b7_row3_col0" class="data row3 col0" >0.275908</td>
#                         <td id="T_8a7b7_row3_col1" class="data row3 col1" >0.240818</td>
#                         <td id="T_8a7b7_row3_col2" class="data row3 col2" >0.285475</td>
#                         <td id="T_8a7b7_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_8a7b7_row3_col4" class="data row3 col4" >0.030173</td>
#                         <td id="T_8a7b7_row3_col5" class="data row3 col5" >0.151888</td>
#             </tr>
#             <tr>
#                         <th id="T_8a7b7_level0_row4" class="row_heading level0 row4" >unempl_rate</th>
#                         <td id="T_8a7b7_row4_col0" class="data row4 col0" >0.212895</td>
#                         <td id="T_8a7b7_row4_col1" class="data row4 col1" >0.245617</td>
#                         <td id="T_8a7b7_row4_col2" class="data row4 col2" >0.172176</td>
#                         <td id="T_8a7b7_row4_col3" class="data row4 col3" >0.030173</td>
#                         <td id="T_8a7b7_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_8a7b7_row4_col5" class="data row4 col5" >0.021044</td>
#             </tr>
#             <tr>
#                         <th id="T_8a7b7_level0_row5" class="row_heading level0 row5" >revenue_rate</th>
#                         <td id="T_8a7b7_row5_col0" class="data row5 col0" >0.172289</td>
#                         <td id="T_8a7b7_row5_col1" class="data row5 col1" >0.109498</td>
#                         <td id="T_8a7b7_row5_col2" class="data row5 col2" >0.276742</td>
#                         <td id="T_8a7b7_row5_col3" class="data row5 col3" >0.151888</td>
#                         <td id="T_8a7b7_row5_col4" class="data row5 col4" >0.021044</td>
#                         <td id="T_8a7b7_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>
# 2016
# <style  type="text/css" >
# #T_34c3b_row0_col0,#T_34c3b_row1_col1,#T_34c3b_row2_col2,#T_34c3b_row3_col3,#T_34c3b_row4_col4,#T_34c3b_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_34c3b_row0_col1{
#             background-color:  #e26952;
#             color:  #000000;
#         }#T_34c3b_row0_col2{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_34c3b_row0_col3{
#             background-color:  #86a9fc;
#             color:  #000000;
#         }#T_34c3b_row0_col4{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_34c3b_row0_col5{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_34c3b_row1_col0{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_34c3b_row1_col2{
#             background-color:  #f29274;
#             color:  #000000;
#         }#T_34c3b_row1_col3{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_34c3b_row1_col4{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_34c3b_row1_col5,#T_34c3b_row5_col2{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_34c3b_row2_col0{
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }#T_34c3b_row2_col1{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_34c3b_row2_col3{
#             background-color:  #89acfd;
#             color:  #000000;
#         }#T_34c3b_row2_col4{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_34c3b_row2_col5{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_34c3b_row3_col0{
#             background-color:  #5875e1;
#             color:  #000000;
#         }#T_34c3b_row3_col1{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_34c3b_row3_col2{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_34c3b_row3_col4{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_34c3b_row3_col5{
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }#T_34c3b_row4_col0,#T_34c3b_row4_col1,#T_34c3b_row4_col2,#T_34c3b_row4_col3,#T_34c3b_row4_col5,#T_34c3b_row5_col4{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_34c3b_row5_col0{
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }#T_34c3b_row5_col1{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_34c3b_row5_col3{
#             background-color:  #7396f5;
#             color:  #000000;
#         }</style><table id="T_34c3b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >pop_rate</th>        <th class="col_heading level0 col1" >migr_rate</th>        <th class="col_heading level0 col2" >age_rate</th>        <th class="col_heading level0 col3" >empl_rate</th>        <th class="col_heading level0 col4" >unempl_rate</th>        <th class="col_heading level0 col5" >revenue_rate</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_34c3b_level0_row0" class="row_heading level0 row0" >pop_rate</th>
#                         <td id="T_34c3b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_34c3b_row0_col1" class="data row0 col1" >0.887821</td>
#                         <td id="T_34c3b_row0_col2" class="data row0 col2" >0.905636</td>
#                         <td id="T_34c3b_row0_col3" class="data row0 col3" >0.279765</td>
#                         <td id="T_34c3b_row0_col4" class="data row0 col4" >0.201849</td>
#                         <td id="T_34c3b_row0_col5" class="data row0 col5" >0.287474</td>
#             </tr>
#             <tr>
#                         <th id="T_34c3b_level0_row1" class="row_heading level0 row1" >migr_rate</th>
#                         <td id="T_34c3b_row1_col0" class="data row1 col0" >0.887821</td>
#                         <td id="T_34c3b_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_34c3b_row1_col2" class="data row1 col2" >0.808815</td>
#                         <td id="T_34c3b_row1_col3" class="data row1 col3" >0.241173</td>
#                         <td id="T_34c3b_row1_col4" class="data row1 col4" >0.214685</td>
#                         <td id="T_34c3b_row1_col5" class="data row1 col5" >0.219063</td>
#             </tr>
#             <tr>
#                         <th id="T_34c3b_level0_row2" class="row_heading level0 row2" >age_rate</th>
#                         <td id="T_34c3b_row2_col0" class="data row2 col0" >0.905636</td>
#                         <td id="T_34c3b_row2_col1" class="data row2 col1" >0.808815</td>
#                         <td id="T_34c3b_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_34c3b_row2_col3" class="data row2 col3" >0.286016</td>
#                         <td id="T_34c3b_row2_col4" class="data row2 col4" >0.183375</td>
#                         <td id="T_34c3b_row2_col5" class="data row2 col5" >0.343356</td>
#             </tr>
#             <tr>
#                         <th id="T_34c3b_level0_row3" class="row_heading level0 row3" >empl_rate</th>
#                         <td id="T_34c3b_row3_col0" class="data row3 col0" >0.279765</td>
#                         <td id="T_34c3b_row3_col1" class="data row3 col1" >0.241173</td>
#                         <td id="T_34c3b_row3_col2" class="data row3 col2" >0.286016</td>
#                         <td id="T_34c3b_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_34c3b_row3_col4" class="data row3 col4" >0.062080</td>
#                         <td id="T_34c3b_row3_col5" class="data row3 col5" >0.230339</td>
#             </tr>
#             <tr>
#                         <th id="T_34c3b_level0_row4" class="row_heading level0 row4" >unempl_rate</th>
#                         <td id="T_34c3b_row4_col0" class="data row4 col0" >0.201849</td>
#                         <td id="T_34c3b_row4_col1" class="data row4 col1" >0.214685</td>
#                         <td id="T_34c3b_row4_col2" class="data row4 col2" >0.183375</td>
#                         <td id="T_34c3b_row4_col3" class="data row4 col3" >0.062080</td>
#                         <td id="T_34c3b_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_34c3b_row4_col5" class="data row4 col5" >0.025997</td>
#             </tr>
#             <tr>
#                         <th id="T_34c3b_level0_row5" class="row_heading level0 row5" >revenue_rate</th>
#                         <td id="T_34c3b_row5_col0" class="data row5 col0" >0.287474</td>
#                         <td id="T_34c3b_row5_col1" class="data row5 col1" >0.219063</td>
#                         <td id="T_34c3b_row5_col2" class="data row5 col2" >0.343356</td>
#                         <td id="T_34c3b_row5_col3" class="data row5 col3" >0.230339</td>
#                         <td id="T_34c3b_row5_col4" class="data row5 col4" >0.025997</td>
#                         <td id="T_34c3b_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>
#               pop_rate  migr_rate  age_rate  empl_rate  unempl_rate  \
# pop_rate      1.000000   0.852199  0.846328   0.245458     0.069966
# migr_rate     0.852199   1.000000  0.713831   0.221194     0.149515
# age_rate      0.846328   0.713831  1.000000   0.255074     0.102756
# empl_rate     0.245458   0.221194  0.255074   1.000000     0.001571
# unempl_rate   0.069966   0.149515  0.102756   0.001571     1.000000
# revenue_rate  0.163016   0.133013  0.209901   0.156791     0.018210
#
#               revenue_rate
# pop_rate          0.163016
# migr_rate         0.133013
# age_rate          0.209901
# empl_rate         0.156791
# unempl_rate       0.018210
# revenue_rate      1.000000

# %%
param_list = [Parameters.POPULATION, Parameters.MIGRATION, Parameters.WORKING_AGE, Parameters.EMPLOYMENT,
              Parameters.UNEMPLOYED, Parameters.REVENUE]

for year in range(2003, 2017):
    for p1 in param_list:
        for p2 in param_list:
            cor = np.corrcoef(df[df['period_start']==year][col1], df[df['period_start']==year][col2], )[0,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-1c0fd0c7a42c> in <module>
#       5     for p1 in param_list:
#       6         for p2 in param_list:
# ----> 7             cor = np.corrcoef(df[df['period_start']==year][col1], df[df['period_start']==year][col2], )[0,1]
#       8
#
# TypeError: 'ExcelFile' object is not subscriptable

# %%
np.corrcoef(df1[df1['period_start']==2003][Parameters.POPULATION], df1[df1['period_start']==2003][Parameters.MIGRATION], df1[df1['period_start']==2003][Parameters.EMPLOYMENT])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-033205a0ab75> in <module>
# ----> 1 np.corrcoef(df1[df1['period_start']==2003][Parameters.POPULATION], df1[df1['period_start']==2003][Parameters.MIGRATION], df1[df1['period_start']==2003][Parameters.EMPLOYMENT])
#
# <__array_function__ internals> in corrcoef(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in corrcoef(x, y, rowvar, bias, ddof, dtype)
#    2632         warnings.warn('bias and ddof have no effect and are deprecated',
#    2633                       DeprecationWarning, stacklevel=3)
# -> 2634     c = cov(x, y, rowvar, dtype=dtype)
#    2635     try:
#    2636         d = diag(c)
#
# <__array_function__ internals> in cov(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\lib\function_base.py in cov(m, y, rowvar, bias, ddof, fweights, aweights, dtype)
#    2418
#    2419     X = array(m, ndmin=2, dtype=dtype)
# -> 2420     if not rowvar and X.shape[0] != 1:
#    2421         X = X.T
#    2422     if X.shape[0] == 0:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1440     @final
#    1441     def __nonzero__(self):
# -> 1442         raise ValueError(
#    1443             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1444             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
